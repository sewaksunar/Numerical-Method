# %% [markdown]
# ## 2 Method of False Position Method

# %% [markdown]
# Importing requred libary

# %%
import numpy as np
import matplotlib.pyplot as pyplot
import pandas as pd

# %% [markdown]
# taking equation input from user

# %%
eq = input("Enter the equation in terms of x using python syntax: ")

# %%
def f(x):
    try:
        return eval(eq)
    except (SyntaxError, NameError, TypeError) as e:
        print("Invalid syntax", e)
        return None
