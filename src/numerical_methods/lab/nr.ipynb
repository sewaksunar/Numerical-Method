# %%
from sympy import *
x, y, z = symbols('x y z')
init_printing(use_unicode=True)

# %%
factor(x**2 + 3*x + 2)
# Out:
# (x + 1)⋅(x + 2)

# %%
factor(5*x + 3*exp(2 - 7*x), deep=True)
# Out:
# ⎛     7⋅x      2⎞  -7⋅x
# ⎝5⋅x⋅ℯ    + 3⋅ℯ ⎠⋅ℯ

# %%
diff(sin(x)*exp(x), x)
# Out:
#  x           x
# ℯ ⋅sin(x) + ℯ ⋅cos(x)
